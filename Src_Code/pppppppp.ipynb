# %%
import pandas as pd

# %%
data = pd.read_csv('E:\Program\[2] Program\AnSent\Data\Data_4_prepro\Pre_Indihome.csv')

# %%
data['Data Teks_Stopword'] = data["Data Teks_Stopword"].astype(str)

# %%
from flashtext import KeywordProcessor

keyword_dict = {
 'jaringan': ['lambat', 'wifi','internet','rusak'],
 'sport': ['cricket','football','baseball']
} 

kp = KeywordProcessor()
kp.add_keywords_from_dict(keyword_dict)

data['category'] = data['Data Teks_Token'].apply(lambda x: kp.extract_keywords(x))

# %%
data1 = data.to_csv('E:\Program\[2] Program\AnSent\Data\Data_7_Relev\katabagku\ssss.csv')

# %%
# data1 = pd.DataFrame({'category':[x for x in data['category'] if x != '' ]})
# data1.drop(index=' ', columns=['category'])

# %%
data
# Out:
#       Unnamed: 0  Unnamed: 0.1                    Tanggal       User ID  \
# 0          12473         12473  2021-10-27 07:31:26+00:00    arifsaadil
# 1           9030          9030  2021-10-11 10:42:41+00:00       tojizru
# 2           8294          8294  2021-10-30 05:33:15+00:00  IndiHomeCare
# 3           9506          9506  2021-10-09 12:36:33+00:00  lalafindyou_
# 4           3036          3036  2021-10-23 11:43:16+00:00      Razyajii
# ...          ...           ...                        ...           ...
# 7027       11852         11852  2021-10-04 16:20:37+00:00    lahanfandi
# 7028       12253         12253  2021-10-27 10:34:12+00:00  Denny_Sega24
# 7029       19858         19858  2021-10-23 05:22:46+00:00  IndiHomeCare
# 7030        4325          4325  2021-10-21 06:15:02+00:00     Telkomsel
# 7031       27289         27289  2021-10-20 21:16:52+00:00  Almond_Mielk
#
#                                               Data Teks  \
# 0     @IndiHomeCare Sudah dilakukan sesuai DM, belum...
# 1                                @chifoeyuu P @IndiHome
# 2     @DilaPong Kak Dila. Uci cek updatenya dijadwal...
# 3     @IndiHome ni kapan ya wifinya bener. Aku mau n...
# 4     Oy Mola TV di Indihome nape tak bisa dibuka, a...
# ...                                                 ...
# 7027                    maap @IndiHome sudah su'udzon 😌
# 7028  @IndiHomeCare min koneksi lost koneksi.. indik...
# 7029  @aintjinani Halo, Kak Nana.\n\nUntuk DM nya su...
# 7030  @tettyrhs Hai, Kak Tettyrhs. Maaf ya, terkait ...
# 7031  @IndiHomeCare Sudah ya min 12 digit tuh mohon ...
#
#                                   Data Teks_CaseFolding  \
# 0                     sudah dilakukan sesuai belum bisa
# 1                                                   NaN
# 2     kak dila uci cek updatenya dijadwalkan kembali...
# 3      kapan wifinya bener aku mau nugas hikdddd pad...
# 4      mola indihome nape tak bisa dibuka appsnya il...
# ...                                                 ...
# 7027                                   maap sudah udzon
# 7028  min koneksi lost koneksi indikator los kedip m...
# 7029  halo kak nana untuk nya sudah bantu respon kak...
# 7030  hai kak tettyrhs maaf terkait informasi atau k...
# 7031       sudah min digit tuh mohon bantuannya makasih
#
#                                    Data Teks_clean_alay  \
# 0                     sudah dilakukan sesuai belum bisa
# 1                                                   NaN
# 2     kak dila uci  periksa updatenya dijadwalkan ke...
# 3      kapan wifinya  benar aku mau nugas hikdddd pa...
# 4      mola indihome nape tak bisa dibuka appsnya il...
# ...                                                 ...
# 7027                                   maap sudah udzon
# 7028   admin koneksi lost koneksi indikator  rusak k...
# 7029  halo kak nana untuk nya sudah bantu respon kak...
# 7030  hai kak tettyrhs maaf terkait informasi atau k...
# 7031    sudah  admin digit tuh mohon bantuannya makasih
#
#                                         Data Teks_Token  \
# 0     ['sudah', 'dilakukan', 'sesuai', 'belum', 'bisa']
# 1                                                  ['']
# 2     ['kak', 'dila', 'uci', 'periksa', 'updatenya',...
# 3     ['', 'kapan', 'wifinya', 'benar', 'aku', 'mau'...
# 4     ['', 'mola', 'indihome', 'nape', 'tak', 'bisa'...
# ...                                                 ...
# 7027                         ['maap', 'sudah', 'udzon']
# 7028  ['', 'admin', 'koneksi', 'lost', 'koneksi', 'i...
# 7029  ['halo', 'kak', 'nana', 'untuk', 'nya', 'sudah...
# 7030  ['hai', 'kak', 'tettyrhs', 'maaf', 'terkait', ...
# 7031  ['sudah', 'admin', 'digit', 'tuh', 'mohon', 'b...
#
#                                      Data Teks_Stopword  \
# 0                                            ['sesuai']
# 1                                                  ['']
# 2     ['dila', 'uci', 'periksa', 'updatenya', 'dijad...
# 3     ['', 'wifinya', 'nugas', 'hikdddd', 'dah', 'ba...
# 4     ['', 'mola', 'indihome', 'nape', 'dibuka', 'ap...
# ...                                                 ...
# 7027                                  ['maap', 'udzon']
# 7028  ['', 'admin', 'koneksi', 'lost', 'koneksi', 'i...
# 7029  ['halo', 'nana', 'bantu', 'respon', 'silakan',...
# 7030  ['hai', 'tettyrhs', 'maaf', 'terkait', 'inform...
# 7031  ['admin', 'digit', 'mohon', 'bantuannya', 'mak...
#
#                                      Data Teks_Stemming    category
# 0                                                sesuai          []
# 1                                                   NaN          []
# 2     dila uci periksa updatenya dijadwalkan esok ja...          []
# 3                       wifinya nugas hikdddd dah bayar          []
# 4               mola indihome nape dibuka appsnya ilang          []
# ...                                                 ...         ...
# 7027                                         maap udzon          []
# 7028   admin koneksi lost koneksi indikator rusak ke...  [jaringan]
# 7029  halo nana bantu respon silakan periksa terima ...          []
# 7030  hai tettyrhs maaf terkait informasi keluhan se...          []
# 7031               admin digit mohon bantuannya makasih          []
#
# [7032 rows x 11 columns]

# %%
data1.to_csv('E:\Program\[2] Program\AnSent\Data\Data_7_Relev\indihiiiii.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13348/3331081230.py in <module>
# ----> 1 data1.to_csv('E:\Program\[2] Program\AnSent\Data\Data_7_Relev\indihiiiii.csv')
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %%
data.append(data1, ignore_index=True)
